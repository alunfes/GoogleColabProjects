# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import time
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import os
import multiprocessing as mp
import numpy as np
import itertools

# %%
directory = '/content/drive/My Drive/MarketData/ohlc'

# %%
def decide_start_end_ts():
    # 各銘柄の最初と最後のタイムスタンプを保存するための辞書
    timestamps = {}

    cleansed_files = [f for f in os.listdir(directory) if f.startswith('cleansed_') and f.endswith('.csv')]

    # Delete all cleansed files
    for f in cleansed_files:
        os.remove(os.path.join(directory, f))

    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            # タイムスタンプの最小値と最大値を取得
            min_ts, max_ts = df['timestamp'].min(), df['timestamp'].max()
            # 銘柄名（ファイル名から拡張子を除去）と対応するタイムスタンプを保存
            timestamps[filename.rsplit('.', 1)[0]] = (min_ts, max_ts)

    # 全銘柄が持つ共通の最小と最大のタイムスタンプを取得
    common_min_ts = max(t[0] for t in timestamps.values())
    common_max_ts = min(t[1] for t in timestamps.values())

    # タイムスタンプをISOフォーマットの日付に変換
    common_min_date = datetime.utcfromtimestamp(common_min_ts/1000).isoformat()
    common_max_date = datetime.utcfromtimestamp(common_max_ts/1000).isoformat()

    # 対象期間の長さを計算
    period_length = (common_max_ts - common_min_ts) / (1000 * 60 * 60 * 24)  # ミリ秒を日数に変換

    print(f'Common start timestamp: {common_min_ts} ({common_min_date})')
    print(f'Common end timestamp: {common_max_ts} ({common_max_date})')
    print(f'The length of the period: {period_length} days')
    return common_min_ts, common_max_ts


common_min_ts, common_max_ts = decide_start_end_ts()
# Out:
# Common start timestamp: 1686220560000 (2023-06-08T10:36:00)
# Common end timestamp: 1686811260000 (2023-06-15T06:41:00)
# The length of the period: 6.836805555555555 days

# %%
def determine_timestamps(directory: str, x: float):
    # 各銘柄の最初と最後のタイムスタンプを保存するための辞書
    timestamps = {}

    for filename in os.listdir(directory):
        if filename.endswith(".csv"):
            file_path = os.path.join(directory, filename)
            df = pd.read_csv(file_path)
            # タイムスタンプの最小値と最大値を取得
            min_ts, max_ts = df['timestamp'].min(), df['timestamp'].max()
            # データ範囲を計算
            range_ts = max_ts - min_ts
            # 銘柄名（ファイル名から拡張子を除去）と対応するタイムスタンプを保存
            timestamps[filename.rsplit('.', 1)[0]] = (min_ts, max_ts, range_ts)

    # データ範囲で銘柄をソート
    sorted_symbols = sorted(timestamps.items(), key=lambda item: item[1][2], reverse=True)

    # 上位x%の銘柄の最初と最後のタイムスタンプを取得
    num_symbols = int(len(sorted_symbols) * x)
    selected_symbols = sorted_symbols[:num_symbols]
    common_min_ts = max(t[1][0] for t in selected_symbols)
    common_max_ts = min(t[1][1] for t in selected_symbols)

    # その期間のデータが存在する全ての銘柄を選択
    final_symbols = [symbol for symbol, ts in timestamps.items() if ts[0] <= common_min_ts and ts[1] >= common_max_ts]

    # タイムスタンプをISOフォーマットの日付に変換
    common_min_date = datetime.utcfromtimestamp(common_min_ts/1000).isoformat()
    common_max_date = datetime.utcfromtimestamp(common_max_ts/1000).isoformat()

    # 対象期間の長さを計算
    period_length = (common_max_ts - common_min_ts) / (1000 * 60 * 60 * 24)  # ミリ秒を日数に変換
    print(f'Common start timestamp: {common_min_ts} ({common_min_date})')
    print(f'Common end timestamp: {common_max_ts} ({common_max_date})')
    print(f'The length of the period: {period_length} days')
    print(f'Num Selected symbols: {len(final_symbols)}')
    return common_min_ts, common_max_ts, final_symbols

# 関数を実行

common_min_ts, common_max_ts, final_symbols = determine_timestamps(directory, 0.5)  # 例として全体の10%の銘柄を最初に選択します
# Out:
# Common start timestamp: 1684219380000 (2023-05-16T06:43:00)
# Common end timestamp: 1686811320000 (2023-06-15T06:42:00)
# The length of the period: 29.999305555555555 days
# Num Selected symbols: 367

# %%
def cleanse_data(directory: str, final_symbols: list, common_min_ts: int, common_max_ts: int, interval: int):
    cleansed_data = {}
    for filename in final_symbols:
        file_path = os.path.join(directory, filename+'.csv')
        df = pd.read_csv(file_path)

        # クレンジング前のデータの長さ
        original_length = len(df)

        # 開始・終了のタイムスタンプを基準値に合わせてそれ以前・以降のデータを削除
        df = df[(df['timestamp'] >= common_min_ts) & (df['timestamp'] <= common_max_ts)]
        df = df.drop_duplicates(subset='timestamp')  # 重複を削除

        # タイムスタンプをインデックスに設定
        df.set_index('timestamp', inplace=True)
        # タイムスタンプの間隔が一定でない部分を補間
        df = df.reindex(range(common_min_ts, common_max_ts + 1, interval))

        # 線形補間
        df.interpolate(method='linear', inplace=True)

        # クレンジング後のデータを新しいCSVファイルとして保存
        df.reset_index().to_csv(directory+'/cleansed_'+filename+'.csv', index=False)

        # クレンジング後のデータの長さとの差を取得
        cleansed_length = len(df)
        #print(f'File: {filename}\nOriginal Length: {original_length}\nCleansed Length: {cleansed_length}\nDifference: {cleansed_length - original_length}\n')

        # クレンジング後のデータフレームを辞書に保存
        cleansed_data[filename] = df
    return cleansed_data


# 関数を実行
interval = 60000  # 1分間隔（ミリ秒単位）
cleansed_data = cleanse_data(directory, final_symbols, common_min_ts, common_max_ts, interval)

for k in list(cleansed_data.keys()):
    print(len(cleansed_data[k]), cleansed_data[k].index)
print('Num all target cleansed file=', len(cleansed_data))
# Out:
# File: apexpro-BTC-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-ETH-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-AVAX-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-ARB-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-XRP-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-ATOM-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-DOGE-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-MATIC-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-OP-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-SOL-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-BNB-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-LTC-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-APT-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-LDO-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: apexpro-BLUR-USDC
# Original Length: 43200
# Cleansed Length: 43200
# Difference: 0
#
# File: bybit-10000LADYS-USDT
# Original Length: 43202
# Cleansed Length: 43200
# Difference: -2
#
# File: okx-ETH-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-10000NFT-USDT
# Original Length: 43202
# Cleansed Length: 43200
# Difference: -2
#
# File: bybit-1000BONK-USDT
# Original Length: 43203
# Cleansed Length: 43200
# Difference: -3
#
# File: okx-LTC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-1000BTT-USDT
# Original Length: 43204
# Cleansed Length: 43200
# Difference: -4
#
# File: okx-XRP-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-1000FLOKI-USDT
# Original Length: 43205
# Cleansed Length: 43200
# Difference: -5
#
# File: bybit-1000LUNC-USDT
# Original Length: 43206
# Cleansed Length: 43200
# Difference: -6
#
# File: okx-SOL-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-1000PEPE-USDT
# Original Length: 43207
# Cleansed Length: 43200
# Difference: -7
#
# File: bybit-1000XEC-USDT
# Original Length: 43208
# Cleansed Length: 43200
# Difference: -8
#
# File: okx-DOGE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-1INCH-USDT
# Original Length: 43208
# Cleansed Length: 43200
# Difference: -8
#
# File: okx-FIL-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-AAVE-USDT
# Original Length: 43209
# Cleansed Length: 43200
# Difference: -9
#
# File: bybit-ACH-USDT
# Original Length: 43210
# Cleansed Length: 43200
# Difference: -10
#
# File: okx-PEPE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ADA-USDT
# Original Length: 43211
# Cleansed Length: 43200
# Difference: -11
#
# File: okx-BNB-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-AGIX-USDT
# Original Length: 43212
# Cleansed Length: 43200
# Difference: -12
#
# File: bybit-AGLD-USDT
# Original Length: 43212
# Cleansed Length: 43200
# Difference: -12
#
# File: bybit-AKRO-USDT
# Original Length: 43213
# Cleansed Length: 43200
# Difference: -13
#
# File: okx-1INCH-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ALGO-USDT
# Original Length: 43214
# Cleansed Length: 43200
# Difference: -14
#
# File: bybit-ALICE-USDT
# Original Length: 43215
# Cleansed Length: 43200
# Difference: -15
#
# File: okx-AAVE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ALPHA-USDT
# Original Length: 43216
# Cleansed Length: 43200
# Difference: -16
#
# File: okx-ADA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ANKR-USDT
# Original Length: 43217
# Cleansed Length: 43200
# Difference: -17
#
# File: bybit-ANT-USDT
# Original Length: 43218
# Cleansed Length: 43200
# Difference: -18
#
# File: okx-AGLD-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-APE-USDT
# Original Length: 43219
# Cleansed Length: 43200
# Difference: -19
#
# File: okx-AIDOGE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-API3-USDT
# Original Length: 43219
# Cleansed Length: 43200
# Difference: -19
#
# File: bybit-APT-USDT
# Original Length: 43220
# Cleansed Length: 43200
# Difference: -20
#
# File: okx-ALGO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ARB-USDT
# Original Length: 43221
# Cleansed Length: 43200
# Difference: -21
#
# File: bybit-ARPA-USDT
# Original Length: 43222
# Cleansed Length: 43200
# Difference: -22
#
# File: okx-ALPHA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-AR-USDT
# Original Length: 43223
# Cleansed Length: 43200
# Difference: -23
#
# File: okx-ANT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ASTR-USDT
# Original Length: 43224
# Cleansed Length: 43200
# Difference: -24
#
# File: bybit-ATOM-USDT
# Original Length: 43224
# Cleansed Length: 43200
# Difference: -24
#
# File: okx-APE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-AUDIO-USDT
# Original Length: 43225
# Cleansed Length: 43200
# Difference: -25
#
# File: okx-API3-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-AVAX-USDT
# Original Length: 43226
# Cleansed Length: 43200
# Difference: -26
#
# File: bybit-AXS-USDT
# Original Length: 43227
# Cleansed Length: 43200
# Difference: -27
#
# File: okx-APT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BAKE-USDT
# Original Length: 43227
# Cleansed Length: 43200
# Difference: -27
#
# File: bybit-BAL-USDT
# Original Length: 43228
# Cleansed Length: 43200
# Difference: -28
#
# File: okx-AR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BAND-USDT
# Original Length: 43229
# Cleansed Length: 43200
# Difference: -29
#
# File: bybit-BAT-USDT
# Original Length: 43230
# Cleansed Length: 43200
# Difference: -30
#
# File: okx-ARB-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BCH-USDT
# Original Length: 43231
# Cleansed Length: 43200
# Difference: -31
#
# File: okx-ATOM-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BEL-USDT
# Original Length: 43231
# Cleansed Length: 43200
# Difference: -31
#
# File: bybit-BICO-USDT
# Original Length: 43232
# Cleansed Length: 43200
# Difference: -32
#
# File: okx-AVAX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BIT-USDT
# Original Length: 43233
# Cleansed Length: 43200
# Difference: -33
#
# File: bybit-BLUR-USDT
# Original Length: 43234
# Cleansed Length: 43200
# Difference: -34
#
# File: okx-AXS-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BLZ-USDT
# Original Length: 43234
# Cleansed Length: 43200
# Difference: -34
#
# File: bybit-BNB-USD
# Original Length: 43235
# Cleansed Length: 43200
# Difference: -35
#
# File: okx-BADGER-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BNB-USDT
# Original Length: 43236
# Cleansed Length: 43200
# Difference: -36
#
# File: okx-BAL-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BNX-USDT
# Original Length: 43237
# Cleansed Length: 43200
# Difference: -37
#
# File: bybit-BOBA-USDT
# Original Length: 43237
# Cleansed Length: 43200
# Difference: -37
#
# File: okx-BAND-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BSV-USDT
# Original Length: 43238
# Cleansed Length: 43200
# Difference: -38
#
# File: bybit-BSW-USDT
# Original Length: 43239
# Cleansed Length: 43200
# Difference: -39
#
# File: okx-BAT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: okx-BCH-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: okx-BICO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: okx-BLUR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BTC-USD
# Original Length: 43244
# Cleansed Length: 43200
# Difference: -44
#
# File: okx-BNT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-BTC-USDT
# Original Length: 43245
# Cleansed Length: 43200
# Difference: -45
#
# File: bybit-BUSD-USDT
# Original Length: 43245
# Cleansed Length: 43200
# Difference: -45
#
# File: okx-BSV-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-C98-USDT
# Original Length: 43246
# Cleansed Length: 43200
# Difference: -46
#
# File: bybit-CEEK-USDT
# Original Length: 43247
# Cleansed Length: 43200
# Difference: -47
#
# File: okx-CELO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CELO-USDT
# Original Length: 43248
# Cleansed Length: 43200
# Difference: -48
#
# File: okx-CEL-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CELR-USDT
# Original Length: 43249
# Cleansed Length: 43200
# Difference: -49
#
# File: bybit-CFX-USDT
# Original Length: 43249
# Cleansed Length: 43200
# Difference: -49
#
# File: okx-CETUS-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CHR-USDT
# Original Length: 43250
# Cleansed Length: 43200
# Difference: -50
#
# File: bybit-CHZ-USDT
# Original Length: 43251
# Cleansed Length: 43200
# Difference: -51
#
# File: okx-CFX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CKB-USDT
# Original Length: 43252
# Cleansed Length: 43200
# Difference: -52
#
# File: okx-CHZ-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-COMP-USDT
# Original Length: 43253
# Cleansed Length: 43200
# Difference: -53
#
# File: bybit-CORE-USDT
# Original Length: 43253
# Cleansed Length: 43200
# Difference: -53
#
# File: okx-COMP-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-COTI-USDT
# Original Length: 43254
# Cleansed Length: 43200
# Difference: -54
#
# File: bybit-CREAM-USDT
# Original Length: 43255
# Cleansed Length: 43200
# Difference: -55
#
# File: okx-CORE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CRO-USDT
# Original Length: 43256
# Cleansed Length: 43200
# Difference: -56
#
# File: okx-CRO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CRV-USDT
# Original Length: 43256
# Cleansed Length: 43200
# Difference: -56
#
# File: bybit-CTC-USDT
# Original Length: 43257
# Cleansed Length: 43200
# Difference: -57
#
# File: okx-CRV-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CTK-USDT
# Original Length: 43258
# Cleansed Length: 43200
# Difference: -58
#
# File: bybit-CTSI-USDT
# Original Length: 43259
# Cleansed Length: 43200
# Difference: -59
#
# File: okx-CSPR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-CVC-USDT
# Original Length: 43260
# Cleansed Length: 43200
# Difference: -60
#
# File: bybit-CVX-USDT
# Original Length: 43260
# Cleansed Length: 43200
# Difference: -60
#
# File: okx-CVC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-DAR-USDT
# Original Length: 43261
# Cleansed Length: 43200
# Difference: -61
#
# File: okx-DASH-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-DASH-USDT
# Original Length: 43262
# Cleansed Length: 43200
# Difference: -62
#
# File: bybit-DENT-USDT
# Original Length: 43263
# Cleansed Length: 43200
# Difference: -63
#
# File: okx-DORA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-DGB-USDT
# Original Length: 43263
# Cleansed Length: 43200
# Difference: -63
#
# File: bybit-DODO-USDT
# Original Length: 43264
# Cleansed Length: 43200
# Difference: -64
#
# File: okx-DOT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-DOGE-USDT
# Original Length: 43265
# Cleansed Length: 43200
# Difference: -65
#
# File: bybit-DOT-USDT
# Original Length: 43266
# Cleansed Length: 43200
# Difference: -66
#
# File: okx-DYDX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-DUSK-USDT
# Original Length: 43267
# Cleansed Length: 43200
# Difference: -67
#
# File: okx-EGLD-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-DYDX-USDT
# Original Length: 43267
# Cleansed Length: 43200
# Difference: -67
#
# File: bybit-EDU-USDT
# Original Length: 43268
# Cleansed Length: 43200
# Difference: -68
#
# File: okx-ENJ-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-EGLD-USDT
# Original Length: 43269
# Cleansed Length: 43200
# Difference: -69
#
# File: bybit-ENJ-USDT
# Original Length: 43270
# Cleansed Length: 43200
# Difference: -70
#
# File: okx-ENS-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ENS-USDT
# Original Length: 43270
# Cleansed Length: 43200
# Difference: -70
#
# File: bybit-EOS-USDT
# Original Length: 43271
# Cleansed Length: 43200
# Difference: -71
#
# File: okx-EOS-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ETC-USD
# Original Length: 43272
# Cleansed Length: 43200
# Difference: -72
#
# File: okx-ETC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ETC-USDT
# Original Length: 43273
# Cleansed Length: 43200
# Difference: -73
#
# File: okx-ETHW-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: okx-FITFI-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: okx-FLM-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ETH-USD
# Original Length: 43277
# Cleansed Length: 43200
# Difference: -77
#
# File: okx-FLOKI-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ETH-USDT
# Original Length: 43278
# Cleansed Length: 43200
# Difference: -78
#
# File: okx-FTM-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ETHW-USDT
# Original Length: 43279
# Cleansed Length: 43200
# Difference: -79
#
# File: bybit-FET-USDT
# Original Length: 43280
# Cleansed Length: 43200
# Difference: -80
#
# File: okx-GALA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-FIL-USDT
# Original Length: 43281
# Cleansed Length: 43200
# Difference: -81
#
# File: bybit-FITFI-USDT
# Original Length: 43281
# Cleansed Length: 43200
# Difference: -81
#
# File: okx-GFT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-FLM-USDT
# Original Length: 43282
# Cleansed Length: 43200
# Difference: -82
#
# File: bybit-FLOW-USDT
# Original Length: 43283
# Cleansed Length: 43200
# Difference: -83
#
# File: okx-GMT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-FLR-USDT
# Original Length: 43284
# Cleansed Length: 43200
# Difference: -84
#
# File: okx-GMX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-FTM-USDT
# Original Length: 43284
# Cleansed Length: 43200
# Difference: -84
#
# File: bybit-FXS-USDT
# Original Length: 43285
# Cleansed Length: 43200
# Difference: -85
#
# File: okx-GODS-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-GALA-USDT
# Original Length: 43286
# Cleansed Length: 43200
# Difference: -86
#
# File: bybit-GAL-USDT
# Original Length: 43287
# Cleansed Length: 43200
# Difference: -87
#
# File: okx-GRT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-GFT-USDT
# Original Length: 43288
# Cleansed Length: 43200
# Difference: -88
#
# File: okx-ICP-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-GLMR-USDT
# Original Length: 43288
# Cleansed Length: 43200
# Difference: -88
#
# File: bybit-GMT-USDT
# Original Length: 43289
# Cleansed Length: 43200
# Difference: -89
#
# File: okx-IMX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-GMX-USDT
# Original Length: 43290
# Cleansed Length: 43200
# Difference: -90
#
# File: bybit-GPT-USDT
# Original Length: 43291
# Cleansed Length: 43200
# Difference: -91
#
# File: okx-IOST-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-GRT-USDT
# Original Length: 43291
# Cleansed Length: 43200
# Difference: -91
#
# File: bybit-GTC-USDT
# Original Length: 43292
# Cleansed Length: 43200
# Difference: -92
#
# File: okx-IOTA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-HBAR-USDT
# Original Length: 43293
# Cleansed Length: 43200
# Difference: -93
#
# File: okx-JST-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-HFT-USDT
# Original Length: 43294
# Cleansed Length: 43200
# Difference: -94
#
# File: bybit-HIGH-USDT
# Original Length: 43294
# Cleansed Length: 43200
# Difference: -94
#
# File: okx-KISHU-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-HNT-USDT
# Original Length: 43295
# Cleansed Length: 43200
# Difference: -95
#
# File: bybit-HOOK-USDT
# Original Length: 43296
# Cleansed Length: 43200
# Difference: -96
#
# File: okx-KLAY-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-HOT-USDT
# Original Length: 43297
# Cleansed Length: 43200
# Difference: -97
#
# File: okx-KNC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ICP-USDT
# Original Length: 43298
# Cleansed Length: 43200
# Difference: -98
#
# File: bybit-ICX-USDT
# Original Length: 43298
# Cleansed Length: 43200
# Difference: -98
#
# File: okx-KSM-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ID-USDT
# Original Length: 43300
# Cleansed Length: 43200
# Difference: -100
#
# File: okx-LDO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ILV-USDT
# Original Length: 43301
# Cleansed Length: 43200
# Difference: -101
#
# File: bybit-IMX-USDT
# Original Length: 43301
# Cleansed Length: 43200
# Difference: -101
#
# File: okx-LINK-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-INJ-USDT
# Original Length: 43302
# Cleansed Length: 43200
# Difference: -102
#
# File: okx-LOOKS-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-IOST-USDT
# Original Length: 43303
# Cleansed Length: 43200
# Difference: -103
#
# File: bybit-IOTA-USDT
# Original Length: 43304
# Cleansed Length: 43200
# Difference: -104
#
# File: okx-LPT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-IOTX-USDT
# Original Length: 43304
# Cleansed Length: 43200
# Difference: -104
#
# File: bybit-JASMY-USDT
# Original Length: 43305
# Cleansed Length: 43200
# Difference: -105
#
# File: okx-LRC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-JOE-USDT
# Original Length: 43306
# Cleansed Length: 43200
# Difference: -106
#
# File: bybit-JST-USDT
# Original Length: 43307
# Cleansed Length: 43200
# Difference: -107
#
# File: okx-LUNA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-KAVA-USDT
# Original Length: 43308
# Cleansed Length: 43200
# Difference: -108
#
# File: okx-LUNC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-KDA-USDT
# Original Length: 43308
# Cleansed Length: 43200
# Difference: -108
#
# File: bybit-KLAY-USDT
# Original Length: 43309
# Cleansed Length: 43200
# Difference: -109
#
# File: okx-MAGIC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-KNC-USDT
# Original Length: 43310
# Cleansed Length: 43200
# Difference: -110
#
# File: okx-MANA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-KSM-USDT
# Original Length: 43311
# Cleansed Length: 43200
# Difference: -111
#
# File: bybit-LDO-USDT
# Original Length: 43312
# Cleansed Length: 43200
# Difference: -112
#
# File: okx-MASK-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-LINA-USDT
# Original Length: 43313
# Cleansed Length: 43200
# Difference: -113
#
# File: okx-MATIC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-LINK-USDT
# Original Length: 43314
# Cleansed Length: 43200
# Difference: -114
#
# File: bybit-LIT-USDT
# Original Length: 43314
# Cleansed Length: 43200
# Difference: -114
#
# File: okx-MINA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-LOOKS-USDT
# Original Length: 43315
# Cleansed Length: 43200
# Difference: -115
#
# File: bybit-LPT-USDT
# Original Length: 43316
# Cleansed Length: 43200
# Difference: -116
#
# File: okx-MKR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-LQTY-USDT
# Original Length: 43317
# Cleansed Length: 43200
# Difference: -117
#
# File: bybit-LRC-USDT
# Original Length: 43317
# Cleansed Length: 43200
# Difference: -117
#
# File: okx-NEAR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-LTC-USDT
# Original Length: 43318
# Cleansed Length: 43200
# Difference: -118
#
# File: okx-NEO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-LUNA2-USDT
# Original Length: 43319
# Cleansed Length: 43200
# Difference: -119
#
# File: bybit-MAGIC-USDT
# Original Length: 43320
# Cleansed Length: 43200
# Difference: -120
#
# File: okx-NFT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-MANA-USDT
# Original Length: 43321
# Cleansed Length: 43200
# Difference: -121
#
# File: bybit-MASK-USDT
# Original Length: 43321
# Cleansed Length: 43200
# Difference: -121
#
# File: okx-OMG-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-MATIC-USD
# Original Length: 43322
# Cleansed Length: 43200
# Difference: -122
#
# File: okx-ONT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-MATIC-USDT
# Original Length: 43323
# Cleansed Length: 43200
# Difference: -123
#
# File: bybit-MINA-USDT
# Original Length: 43324
# Cleansed Length: 43200
# Difference: -124
#
# File: okx-OP-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-MKR-USDT
# Original Length: 43324
# Cleansed Length: 43200
# Difference: -124
#
# File: bybit-MTL-USDT
# Original Length: 43325
# Cleansed Length: 43200
# Difference: -125
#
# File: okx-PEOPLE-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-NEAR-USDT
# Original Length: 43326
# Cleansed Length: 43200
# Difference: -126
#
# File: bybit-NEO-USDT
# Original Length: 43327
# Cleansed Length: 43200
# Difference: -127
#
# File: okx-PERP-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-NKN-USDT
# Original Length: 43328
# Cleansed Length: 43200
# Difference: -128
#
# File: okx-QTUM-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-OCEAN-USDT
# Original Length: 43328
# Cleansed Length: 43200
# Difference: -128
#
# File: bybit-OGN-USDT
# Original Length: 43329
# Cleansed Length: 43200
# Difference: -129
#
# File: okx-RDNT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-OMG-USDT
# Original Length: 43330
# Cleansed Length: 43200
# Difference: -130
#
# File: bybit-ONE-USDT
# Original Length: 43331
# Cleansed Length: 43200
# Difference: -131
#
# File: okx-REN-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-ONT-USDT
# Original Length: 43331
# Cleansed Length: 43200
# Difference: -131
#
# File: bybit-OP-USD
# Original Length: 43332
# Cleansed Length: 43200
# Difference: -132
#
# File: okx-RSR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-OP-USDT
# Original Length: 43333
# Cleansed Length: 43200
# Difference: -133
#
# File: okx-RVN-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-PAXG-USDT
# Original Length: 43334
# Cleansed Length: 43200
# Difference: -134
#
# File: okx-SAND-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-PEOPLE-USDT
# Original Length: 43335
# Cleansed Length: 43200
# Difference: -135
#
# File: okx-SHIB-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-QTUM-USDT
# Original Length: 43337
# Cleansed Length: 43200
# Difference: -137
#
# File: okx-SLP-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-RDNT-USDT
# Original Length: 43338
# Cleansed Length: 43200
# Difference: -138
#
# File: bybit-REEF-USDT
# Original Length: 43339
# Cleansed Length: 43200
# Difference: -139
#
# File: okx-SNX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-REN-USDT
# Original Length: 43339
# Cleansed Length: 43200
# Difference: -139
#
# File: bybit-REQ-USDT
# Original Length: 43340
# Cleansed Length: 43200
# Difference: -140
#
# File: okx-STARL-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-RLC-USDT
# Original Length: 43341
# Cleansed Length: 43200
# Difference: -141
#
# File: okx-STORJ-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-RNDR-USDT
# Original Length: 43342
# Cleansed Length: 43200
# Difference: -142
#
# File: bybit-ROSE-USDT
# Original Length: 43342
# Cleansed Length: 43200
# Difference: -142
#
# File: okx-STX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-RPL-USDT
# Original Length: 43343
# Cleansed Length: 43200
# Difference: -143
#
# File: bybit-RSR-USDT
# Original Length: 43344
# Cleansed Length: 43200
# Difference: -144
#
# File: okx-SUI-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-RSS3-USDT
# Original Length: 43345
# Cleansed Length: 43200
# Difference: -145
#
# File: bybit-RUNE-USDT
# Original Length: 43346
# Cleansed Length: 43200
# Difference: -146
#
# File: okx-SUSHI-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-RVN-USDT
# Original Length: 43346
# Cleansed Length: 43200
# Difference: -146
#
# File: okx-SWEAT-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SAND-USDT
# Original Length: 43347
# Cleansed Length: 43200
# Difference: -147
#
# File: bybit-SCRT-USDT
# Original Length: 43348
# Cleansed Length: 43200
# Difference: -148
#
# File: okx-THETA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SC-USDT
# Original Length: 43349
# Cleansed Length: 43200
# Difference: -149
#
# File: bybit-SFP-USDT
# Original Length: 43349
# Cleansed Length: 43200
# Difference: -149
#
# File: okx-TON-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SHIB1000-USDT
# Original Length: 43350
# Cleansed Length: 43200
# Difference: -150
#
# File: okx-TRB-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SKL-USDT
# Original Length: 43351
# Cleansed Length: 43200
# Difference: -151
#
# File: bybit-SLP-USDT
# Original Length: 43352
# Cleansed Length: 43200
# Difference: -152
#
# File: okx-TRX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SNX-USDT
# Original Length: 43353
# Cleansed Length: 43200
# Difference: -153
#
# File: bybit-SOL-USD
# Original Length: 43353
# Cleansed Length: 43200
# Difference: -153
#
# File: okx-UMA-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SOL-USDT
# Original Length: 43354
# Cleansed Length: 43200
# Difference: -154
#
# File: bybit-SPELL-USDT
# Original Length: 43355
# Cleansed Length: 43200
# Difference: -155
#
# File: okx-UNI-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SSV-USDT
# Original Length: 43356
# Cleansed Length: 43200
# Difference: -156
#
# File: okx-USDC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-STG-USDT
# Original Length: 43356
# Cleansed Length: 43200
# Difference: -156
#
# File: bybit-STMX-USDT
# Original Length: 43357
# Cleansed Length: 43200
# Difference: -157
#
# File: okx-USTC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-STORJ-USDT
# Original Length: 43358
# Cleansed Length: 43200
# Difference: -158
#
# File: bybit-STX-USDT
# Original Length: 43359
# Cleansed Length: 43200
# Difference: -159
#
# File: okx-WAVES-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SUI-USDT
# Original Length: 43360
# Cleansed Length: 43200
# Difference: -160
#
# File: okx-WOO-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SUN-USDT
# Original Length: 43360
# Cleansed Length: 43200
# Difference: -160
#
# File: bybit-SUSHI-USDT
# Original Length: 43361
# Cleansed Length: 43200
# Difference: -161
#
# File: okx-XCH-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-SWEAT-USDT
# Original Length: 43362
# Cleansed Length: 43200
# Difference: -162
#
# File: bybit-SXP-USDT
# Original Length: 43363
# Cleansed Length: 43200
# Difference: -163
#
# File: okx-XLM-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-THETA-USDT
# Original Length: 43364
# Cleansed Length: 43200
# Difference: -164
#
# File: okx-XMR-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-TLM-USDT
# Original Length: 43364
# Cleansed Length: 43200
# Difference: -164
#
# File: bybit-TOMO-USDT
# Original Length: 43365
# Cleansed Length: 43200
# Difference: -165
#
# File: okx-XTZ-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-TRB-USDT
# Original Length: 43366
# Cleansed Length: 43200
# Difference: -166
#
# File: bybit-TRU-USDT
# Original Length: 43367
# Cleansed Length: 43200
# Difference: -167
#
# File: okx-YFI-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-TRX-USDT
# Original Length: 43368
# Cleansed Length: 43200
# Difference: -168
#
# File: bybit-T-USDT
# Original Length: 43368
# Cleansed Length: 43200
# Difference: -168
#
# File: okx-YFII-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-TWT-USDT
# Original Length: 43369
# Cleansed Length: 43200
# Difference: -169
#
# File: okx-YGG-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-UNFI-USDT
# Original Length: 43370
# Cleansed Length: 43200
# Difference: -170
#
# File: bybit-UNI-USDT
# Original Length: 43371
# Cleansed Length: 43200
# Difference: -171
#
# File: okx-ZEC-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-USDC-USDT
# Original Length: 43372
# Cleansed Length: 43200
# Difference: -172
#
# File: okx-ZEN-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-VET-USDT
# Original Length: 43372
# Cleansed Length: 43200
# Difference: -172
#
# File: bybit-WAVES-USDT
# Original Length: 43373
# Cleansed Length: 43200
# Difference: -173
#
# File: okx-ZIL-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-WOO-USDT
# Original Length: 43374
# Cleansed Length: 43200
# Difference: -174
#
# File: bybit-XCN-USDT
# Original Length: 43375
# Cleansed Length: 43200
# Difference: -175
#
# File: okx-ZRX-USDT
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-XEM-USDT
# Original Length: 43376
# Cleansed Length: 43200
# Difference: -176
#
# File: okx-BTC-USDC
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-XLM-USDT
# Original Length: 43376
# Cleansed Length: 43200
# Difference: -176
#
# File: bybit-XMR-USDT
# Original Length: 43377
# Cleansed Length: 43200
# Difference: -177
#
# File: okx-ETH-USDC
# Original Length: 43400
# Cleansed Length: 43200
# Difference: -200
#
# File: bybit-XNO-USDT
# Original Length: 43378
# Cleansed Length: 43200
# Difference: -178
#
# File: bybit-XRP-USD
# Original Length: 43379
# Cleansed Length: 43200
# Difference: -179
#
# File: bybit-XRP-USDT
# Original Length: 43380
# Cleansed Length: 43200
# Difference: -180
#
# File: bybit-XTZ-USDT
# Original Length: 43380
# Cleansed Length: 43200
# Difference: -180
#
# File: bybit-YFI-USDT
# Original Length: 43381
# Cleansed Length: 43200
# Difference: -181
#
# File: bybit-YGG-USDT
# Original Length: 43382
# Cleansed Length: 43200
# Difference: -182
#
# File: bybit-ZEC-USDT
# Original Length: 43383
# Cleansed Length: 43200
# Difference: -183
#
# File: bybit-ZEN-USDT
# Original Length: 43384
# Cleansed Length: 43200
# Difference: -184
#
# File: bybit-ZIL-USDT
# Original Length: 43384
# Cleansed Length: 43200
# Difference: -184
#
# File: bybit-ZRX-USDT
# Original Length: 43385
# Cleansed Length: 43200
# Difference: -185
#
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')
# 43200 RangeIndex(start=1684219380000, stop=1686811320001, step=60000, name='timestamp')

# %%
# 並列化のための関数定義
def calculate_corr(args):
    pair, period = args
    df1 = pd.read_csv(pair[0], index_col='timestamp')
    df2 = pd.read_csv(pair[1], index_col='timestamp')

    # 指定したタイムスタンプ以前の指定した期間（period分）のデータを取得
    timestamp = df1.index.max()  # 最新のタイムスタンプを取得
    start_timestamp = timestamp - period * 60 * 1000  # 開始タイムスタンプを計算（ミリ秒単位）

    df1 = df1[df1.index >= start_timestamp]
    df2 = df2[df2.index >= start_timestamp]

    return (pair, df1['close'].corr(df2['close']))


def estimate_processing_time(num_files, period):
    # cleansedという文字から始まるファイルを全て読み込む
    cleansed_files = [os.path.join(directory, f) for f in os.listdir(directory) if f.startswith('cleansed_') and f.endswith('.csv')]

    # ファイルを指定した数に限定
    cleansed_files = cleansed_files[:num_files]

    # 銘柄ペアのリストを作成
    symbol_pairs = list(itertools.combinations(cleansed_files, 2))

    # periodを含む引数リストを作成
    args = [(pair, period) for pair in symbol_pairs]

    # 処理開始時間を記録
    start_time = time.time()

    # multiprocessing Poolを使って並列化
    with mp.Pool(mp.cpu_count()) as pool:
        results = pool.map(calculate_corr, args)

    # 処理終了時間を記録
    end_time = time.time()

    # 結果を表示
    for result in results:
        print(f"Correlation between {result[0][0]} and {result[0][1]}: {result[1]}")


    # 処理時間を表示
    print(f"Processing time for {num_files} files: {end_time - start_time} seconds")

    # 全体の処理時間を推測
    total_files = len([f for f in os.listdir(directory) if f.startswith('cleansed_') and f.endswith('.csv')])
    estimated_time = (end_time - start_time) * ((total_files * (total_files - 1)) / (num_files * (num_files - 1)))
    print(f"Estimated processing time for all files: {estimated_time} seconds")

    return results

# 関数を呼び出す
results = estimate_processing_time(num_files=10, period=1440)
# Out:
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv: 0.9942618477352133
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv: 0.9721537798938183
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv: 0.9938126142395962
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv: 0.9741347141126504
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv: 0.7966198902161407
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv: 0.9726080442124184
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.986876840971363
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.9891068066840758
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-BTC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.87747781350554
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv: 0.9719061700946455
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv: 0.9889170060209743
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv: 0.9821169570447411
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv: 0.7787241286500427
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv: 0.9776546466180177
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.9852419655157437
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.9915594542386853
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ETH-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.891355213494678
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv: 0.9745144333900476
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv: 0.9704503465950456
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv: 0.861683316096185
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv: 0.9690600718428565
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.9823471540618601
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.9762018659168339
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-AVAX-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.9357364340306913
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv: 0.972339836601473
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv: 0.8131692971236473
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv: 0.969183444152796
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.9875116048927862
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.9919700640853144
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ARB-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.8846955311281781
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv: 0.8003098591936593
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv: 0.9814481262898433
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.9719159488107585
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.977843485744743
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-XRP-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.9213308026592528
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv: 0.8125391883459294
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.8540184561584189
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.8161598001880681
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-ATOM-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.8935192080436336
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv: 0.9751762191283548
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.9757964084417565
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-DOGE-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.9178157951002812
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv: 0.9916230322031728
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-MATIC-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.9210837889826844
# Correlation between /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-OP-USDC.csv and /content/drive/My Drive/MarketData/ohlc/cleansed_apexpro-SOL-USDC.csv: 0.9048697441651363
# Processing time for 10 files: 3.281564474105835 seconds
# Estimated processing time for all files: 4897.625592120488 seconds

# %%
estimated_time = (end_time - start_time) * ((total_files * (total_files - 1)) / (100 * (100 - 1)))

# %%
estimated_time
# Out:
# 4065.7320813663077

# %%
mp.cpu_count()
# Out:
# 2

# %%
# !cat /proc/cpuinfo | grep 'model name' | uniq
# !cat /proc/cpuinfo | grep 'processor' | uniq
# Out:
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# processor	: 0
# processor	: 1
