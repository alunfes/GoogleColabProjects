# %% [markdown]
# <a href="https://colab.research.google.com/github/alunfes/GoogleColabProjects/blob/main/FundPlotlyTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import plotly.express as px
import pandas as pd
import numpy as np

# サンプルデータの作成（ここでは仮のデータを使用します）
np.random.seed(0)
num_funds = 20
data = {
    'ファンド名': [f'ファンド{i}' for i in range(1, num_funds + 1)],
    '純資産額': np.random.randint(500, 2000, num_funds),
    '前日変化率': np.random.uniform(-0.05, 0.05, num_funds)  # ランダムな変化率
}

df = pd.DataFrame(data)

# 変化率の符号に基づいて色を設定
df['色'] = df['前日変化率'].apply(lambda x: '緑' if x >= 0 else '赤')

# 全体の合計額を計算
total_value = df['純資産額'].sum()

# 全体の合計額を除いたデータを作成
df_filtered = df[df['ファンド名'] != '全体']

# icicleグラフのプロット
fig = px.treemap(df_filtered, path=['ファンド名'], values='純資産額', color='色',
                 hover_data={'ファンド名': True, '純資産額': True, '前日変化率': True},
                 labels={'純資産額': '純資産額', '前日変化率': '前日変化率'})
fig.update_layout(title='ファンドの純資産額と前日変化率（icicleグラフ）',
                  xaxis_title='ファンド名',
                  yaxis_title='純資産額',
                  showlegend=False)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e675ec1e-177d-4d57-b996-d6c3825ee55b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e675ec1e-177d-4d57-b996-d6c3825ee55b")) {                    Plotly.newPlot(                        "e675ec1e-177d-4d57-b996-d6c3825ee55b",                        [{"branchvalues":"total","customdata":[["\u30d5\u30a1\u30f3\u30c918",674,0.027423368943421664,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c97",1533,0.0478618342232764,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c94",1335,0.0332619845547938,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c93",1716,-0.047978160255967434,"\u8d64"],["\u30d5\u30a1\u30f3\u30c92",1059,-0.04128707002984593,"\u8d64"],["\u30d5\u30a1\u30f3\u30c916",1051,-0.008533806000947643,"\u8d64"],["\u30d5\u30a1\u30f3\u30c99",1099,-0.0038520637747068154,"\u8d64"],["\u30d5\u30a1\u30f3\u30c914",814,0.04446689170495839,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c913",1920,-0.035664671259095365,"\u8d64"],["\u30d5\u30a1\u30f3\u30c912",1100,0.013992102132752385,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c915",1205,0.002184832175007166,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c917",587,-0.023544438789537304,"\u8d64"],["\u30d5\u30a1\u30f3\u30c98",777,0.029915856421672368,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c919",1349,-0.004384966778345142,"\u8d64"],["\u30d5\u30a1\u30f3\u30c920",1037,0.006843394886864848,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c911",1996,-0.038172557413106684,"\u8d64"],["\u30d5\u30a1\u30f3\u30c95",1263,0.027815675094985046,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c96",1883,0.037001214824681924,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c910",1594,0.02805291762864555,"\u7dd1"],["\u30d5\u30a1\u30f3\u30c91",1184,-0.04289639418021131,"\u8d64"]],"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}\u003cbr\u003e\u7d14\u8cc7\u7523\u984d=%{customdata[1]}\u003cbr\u003eparent=%{parent}\u003cbr\u003eid=%{id}\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=%{customdata[0]}\u003cbr\u003e\u524d\u65e5\u5909\u5316\u7387=%{customdata[2]}\u003cbr\u003e\u8272=%{customdata[3]}\u003cextra\u003e\u003c\u002fextra\u003e","ids":["\u30d5\u30a1\u30f3\u30c918","\u30d5\u30a1\u30f3\u30c97","\u30d5\u30a1\u30f3\u30c94","\u30d5\u30a1\u30f3\u30c93","\u30d5\u30a1\u30f3\u30c92","\u30d5\u30a1\u30f3\u30c916","\u30d5\u30a1\u30f3\u30c99","\u30d5\u30a1\u30f3\u30c914","\u30d5\u30a1\u30f3\u30c913","\u30d5\u30a1\u30f3\u30c912","\u30d5\u30a1\u30f3\u30c915","\u30d5\u30a1\u30f3\u30c917","\u30d5\u30a1\u30f3\u30c98","\u30d5\u30a1\u30f3\u30c919","\u30d5\u30a1\u30f3\u30c920","\u30d5\u30a1\u30f3\u30c911","\u30d5\u30a1\u30f3\u30c95","\u30d5\u30a1\u30f3\u30c96","\u30d5\u30a1\u30f3\u30c910","\u30d5\u30a1\u30f3\u30c91"],"labels":["\u30d5\u30a1\u30f3\u30c918","\u30d5\u30a1\u30f3\u30c97","\u30d5\u30a1\u30f3\u30c94","\u30d5\u30a1\u30f3\u30c93","\u30d5\u30a1\u30f3\u30c92","\u30d5\u30a1\u30f3\u30c916","\u30d5\u30a1\u30f3\u30c99","\u30d5\u30a1\u30f3\u30c914","\u30d5\u30a1\u30f3\u30c913","\u30d5\u30a1\u30f3\u30c912","\u30d5\u30a1\u30f3\u30c915","\u30d5\u30a1\u30f3\u30c917","\u30d5\u30a1\u30f3\u30c98","\u30d5\u30a1\u30f3\u30c919","\u30d5\u30a1\u30f3\u30c920","\u30d5\u30a1\u30f3\u30c911","\u30d5\u30a1\u30f3\u30c95","\u30d5\u30a1\u30f3\u30c96","\u30d5\u30a1\u30f3\u30c910","\u30d5\u30a1\u30f3\u30c91"],"marker":{"colors":["#636efa","#636efa","#636efa","#EF553B","#EF553B","#EF553B","#EF553B","#636efa","#EF553B","#636efa","#636efa","#EF553B","#636efa","#EF553B","#636efa","#EF553B","#636efa","#636efa","#636efa","#EF553B"]},"name":"","parents":["","","","","","","","","","","","","","","","","","","",""],"values":[674,1533,1335,1716,1059,1051,1099,814,1920,1100,1205,587,777,1349,1037,1996,1263,1883,1594,1184],"type":"treemap"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewi ...

# %%
import plotly.graph_objects as go
import pandas as pd

# サンプルデータの作成（ここでは仮のデータを使用します）
data = {
    'ファンド名': ['ファンドA', 'ファンドB', 'ファンドC', 'ファンドD', 'ファンドE'],
    'アセットクラス': ['株式', '債券', '株式', '債券', '商品'],
    '純資産額': [1000, 1500, 800, 1200, 700]
}

df = pd.DataFrame(data)

# アセットクラスごとに純資産額を合計
df_agg = df.groupby('アセットクラス')['純資産額'].sum().reset_index()

# 各ファンドの割合を計算
df = pd.merge(df, df_agg, on='アセットクラス', suffixes=('', '_合計'))
df['割合'] = df['純資産額'] / df['純資産額_合計']

# 色の設定
colors = px.colors.qualitative.Set3

# グラフの作成
fig = go.Figure()

for asset_class, color in zip(df['アセットクラス'].unique(), colors):
    df_subset = df[df['アセットクラス'] == asset_class]
    fig.add_trace(go.Bar(
        x=[asset_class] * len(df_subset),
        y=df_subset['純資産額'],
        text=df_subset['ファンド名'] + ': ' + df_subset['純資産額'].astype(str),
        name=asset_class,
        marker=dict(color=color),
        hoverinfo='text'
    ))

fig.update_layout(title='アセットクラスごとのファンドの純資産額',
                  xaxis_title='アセットクラス',
                  yaxis_title='純資産額',
                  barmode='stack')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ee69bd62-e6ee-4d85-82c6-468287236d57" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ee69bd62-e6ee-4d85-82c6-468287236d57")) {                    Plotly.newPlot(                        "ee69bd62-e6ee-4d85-82c6-468287236d57",                        [{"hoverinfo":"text","marker":{"color":"rgb(141,211,199)"},"name":"\u682a\u5f0f","text":["\u30d5\u30a1\u30f3\u30c9A: 1000","\u30d5\u30a1\u30f3\u30c9C: 800"],"x":["\u682a\u5f0f","\u682a\u5f0f"],"y":[1000,800],"type":"bar"},{"hoverinfo":"text","marker":{"color":"rgb(255,255,179)"},"name":"\u50b5\u5238","text":["\u30d5\u30a1\u30f3\u30c9B: 1500","\u30d5\u30a1\u30f3\u30c9D: 1200"],"x":["\u50b5\u5238","\u50b5\u5238"],"y":[1500,1200],"type":"bar"},{"hoverinfo":"text","marker":{"color":"rgb(190,186,218)"},"name":"\u5546\u54c1","text":["\u30d5\u30a1\u30f3\u30c9E: 700"],"x":["\u5546\u54c1"],"y":[700],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f" ...

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px

# サンプルデータの作成
np.random.seed(0)
num_days = 30
num_funds = 5
num_companies = 3

data = {
    '日付': pd.date_range(start='2024-01-01', periods=num_days),
    'ファンド名': np.random.choice([f'ファンド{i}' for i in range(1, num_funds + 1)], num_days),
    '販売会社': np.random.choice([f'会社{j}' for j in range(1, num_companies + 1)], num_days),
    '設定量': np.random.randint(10, 100, num_days),
    '解約量': np.random.randint(5, 50, num_days)
}

df = pd.DataFrame(data)

# 時系列グラフ
fig1 = px.line(df, x='日付', y='設定量', color='販売会社', line_group='ファンド名', title='販売会社ごとの設定量の時系列グラフ')
fig1.update_layout(xaxis_title='日付', yaxis_title='設定量')

fig2 = px.line(df, x='日付', y='解約量', color='販売会社', line_group='ファンド名', title='販売会社ごとの解約量の時系列グラフ')
fig2.update_layout(xaxis_title='日付', yaxis_title='解約量')

# 積み上げ面グラフ
df_stacked = df.groupby(['日付', '販売会社']).agg({'設定量': 'sum', '解約量': 'sum'}).reset_index()

fig3 = px.area(df_stacked, x='日付', y=['設定量', '解約量'], color='販売会社', title='販売会社ごとの設定・解約量の積み上げ面グラフ')
fig3.update_layout(xaxis_title='日付', yaxis_title='量')

# 散布図
fig4 = px.scatter(df, x='設定量', y='解約量', color='販売会社', title='販売会社ごとの設定量と解約量の散布図')
fig4.update_layout(xaxis_title='設定量', yaxis_title='解約量')

fig1.show()
fig2.show()
fig3.show()
fig4.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c6404287-1175-4ba2-9790-ea3b5c368805" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6404287-1175-4ba2-9790-ea3b5c368805")) {                    Plotly.newPlot(                        "c6404287-1175-4ba2-9790-ea3b5c368805",                        [{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c95\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00","2024-01-09T00:00:00","2024-01-12T00:00:00"],"xaxis":"x","y":[45,52,78],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c91\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"x":["2024-01-10T00:00:00","2024-01-18T00:00:00","2024-01-24T00:00:00"],"xaxis":"x","y":[94,62,89],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c94\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"x":["2024-01-07T00:00:00"],"xaxis":"x","y":[63],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c93\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"x":["2024-01-25T00:00:00"],"xaxis":"x","y":[23],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c95\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e1","orientation":"v","showlegend":true,"x":["2024-01-20T00:00:00"],"xaxis":"x","y":[25],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c91\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e1","orientation":"v","showlegend":false,"x":["2024-01-02T00:00:00","2024-01-11T00:00:00","2024-01-15T00:00:00","2024-01-22T00:00:00"],"xaxis":"x","y":[21,85,57,68],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c94\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B","dash":"solid"},"marker": ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c3f723c5-9ff8-44e3-902b-654d6dc67197" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c3f723c5-9ff8-44e3-902b-654d6dc67197")) {                    Plotly.newPlot(                        "c3f723c5-9ff8-44e3-902b-654d6dc67197",                        [{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c95\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":true,"x":["2024-01-01T00:00:00","2024-01-09T00:00:00","2024-01-12T00:00:00"],"xaxis":"x","y":[40,34,47],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c91\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"x":["2024-01-10T00:00:00","2024-01-18T00:00:00","2024-01-24T00:00:00"],"xaxis":"x","y":[8,15,35],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c94\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"x":["2024-01-07T00:00:00"],"xaxis":"x","y":[41],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c93\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"x":["2024-01-25T00:00:00"],"xaxis":"x","y":[8],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c95\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e1","orientation":"v","showlegend":true,"x":["2024-01-20T00:00:00"],"xaxis":"x","y":[28],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c91\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e1","orientation":"v","showlegend":false,"x":["2024-01-02T00:00:00","2024-01-11T00:00:00","2024-01-15T00:00:00","2024-01-22T00:00:00"],"xaxis":"x","y":[5,39,26,39],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u30d5\u30a1\u30f3\u30c9\u540d=\u30d5\u30a1\u30f3\u30c94\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B","dash":"solid"},"marker":{"s ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="45172aa6-207c-4f27-8a2f-d7ba8afdc440" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("45172aa6-207c-4f27-8a2f-d7ba8afdc440")) {                    Plotly.newPlot(                        "45172aa6-207c-4f27-8a2f-d7ba8afdc440",                        [{"fillpattern":{"shape":""},"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003evariable=\u8a2d\u5b9a\u91cf\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":true,"stackgroup":"1","x":["2024-01-01T00:00:00","2024-01-07T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-12T00:00:00","2024-01-18T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00"],"xaxis":"x","y":[45,63,52,94,78,62,89,23],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003evariable=\u89e3\u7d04\u91cf\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","line":{"color":"#636efa"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e3","orientation":"v","showlegend":false,"stackgroup":"1","x":["2024-01-01T00:00:00","2024-01-07T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-12T00:00:00","2024-01-18T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00"],"xaxis":"x","y":[40,41,34,8,47,15,35,8],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003evariable=\u8a2d\u5b9a\u91cf\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e1","orientation":"v","showlegend":true,"stackgroup":"1","x":["2024-01-02T00:00:00","2024-01-06T00:00:00","2024-01-08T00:00:00","2024-01-11T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-22T00:00:00","2024-01-26T00:00:00"],"xaxis":"x","y":[21,24,22,85,16,78,57,88,25,68,95],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003evariable=\u89e3\u7d04\u91cf\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","line":{"color":"#EF553B"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e1","orientation":"v","showlegend":false,"stackgroup":"1","x":["2024-01-02T00:00:00","2024-01-06T00:00:00","2024-01-08T00:00:00","2024-01-11T00:00:00","2024-01-13T00:00:00","2024-01-14T00:00:00","2024-01-15T00:00:00","2024-01-19T00:00:00","2024-01-20T00:00:00","2024-01-22T00:00:00","2024-01-26T00:00:00"],"xaxis":"x","y":[5,5,39,39,18,44,26,48,28,39,23],"yaxis":"y","type":"scatter"},{"fillpattern":{"shape":""},"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e2\u003cbr\u003evariable=\u8a2d\u5b9a\u91cf\u003cbr\u003e\u65e5\u4ed8=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e2","line":{"color":"#00cc96"},"marker":{"symbol":"circle"},"mode":"lines","name":"\u4f1a\u793e2","orientation":"v","showlegend":true,"stackgroup":"1","x":["2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-21T00:00:00","2024-01-23T00:00:00","2024-01-27T00:00:00","2024-01-28T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00"],"xaxis":"x","y":[56,92,10,13,86,30 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="96915420-fa12-416b-be23-f76272b6e4a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96915420-fa12-416b-be23-f76272b6e4a3")) {                    Plotly.newPlot(                        "96915420-fa12-416b-be23-f76272b6e4a3",                        [{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e3\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e3","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"\u4f1a\u793e3","orientation":"v","showlegend":true,"x":[45,63,52,94,78,62,89,23],"xaxis":"x","y":[40,41,34,8,47,15,35,8],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e1\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e1","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"\u4f1a\u793e1","orientation":"v","showlegend":true,"x":[21,24,22,85,16,78,57,88,25,68,95],"xaxis":"x","y":[5,5,39,39,18,44,26,48,28,39,23],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u8ca9\u58f2\u4f1a\u793e=\u4f1a\u793e2\u003cbr\u003e\u8a2d\u5b9a\u91cf=%{x}\u003cbr\u003e\u89e3\u7d04\u91cf=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"\u4f1a\u793e2","marker":{"color":"#00cc96","symbol":"circle"},"mode":"markers","name":"\u4f1a\u793e2","orientation":"v","showlegend":true,"x":[56,92,10,13,86,30,33,58,59,79,51],"xaxis":"x","y":[36,10,35,14,5,7,40,40,25,22,32],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlin ...
